# %%
from scripts.analyze_python_chars import count_chars, chars_as_frame
from pathlib import Path

counts = count_chars(Path.home() / "Code")
chars_as_frame(counts).style
# Out:
# <style type="text/css">
# </style>
# <table id="T_529da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_529da_level0_col0" class="col_heading level0 col0" >sync.py</th>
#       <th id="T_529da_level0_col1" class="col_heading level0 col1" >analyze_python_chars.py</th>
#       <th id="T_529da_level0_col2" class="col_heading level0 col2" >database_test.py</th>
#       <th id="T_529da_level0_col3" class="col_heading level0 col3" >definitions_test.py</th>
#       <th id="T_529da_level0_col4" class="col_heading level0 col4" >units_test.py</th>
#       <th id="T_529da_level0_col5" class="col_heading level0 col5" >datafile_test.py</th>
#       <th id="T_529da_level0_col6" class="col_heading level0 col6" >__init__.py</th>
#       <th id="T_529da_level0_col7" class="col_heading level0 col7" >models_test.py</th>
#       <th id="T_529da_level0_col8" class="col_heading level0 col8" >build_db.py</th>
# ...
